# %%
import sys
import os

# Add the project root directory to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now you can import from scripts
from scripts.stock_analysis import (
    load_stock_data,
    calculate_technical_indicators,
    calculate_financial_metrics,
    plot_stock_analysis
)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/AAPL_historical_data.csv'
stock_symbol = 'AAPL'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/AMZN_historical_data.csv'
stock_symbol = 'AMZN'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/GOOG_historical_data.csv'
stock_symbol = 'GOOG'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/META_historical_data.csv'
stock_symbol = 'META'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/MSFT_historical_data.csv'
stock_symbol = 'MSFT'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/NVDA_historical_data.csv'
stock_symbol = 'NVDA'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)
# Out:
# c:\Users\fikre\Financial-News-and-Stock-Price\venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 1. Specify stock file and symbol
stock_file = '../yfinance_data/TSLA_historical_data.csv'
stock_symbol = 'TSLA'

# 2. Load and process the data
df = load_stock_data(stock_file)
df = calculate_technical_indicators(df)
df = calculate_financial_metrics(df)

# 3. Generate and display the analysis plot
fig = plot_stock_analysis(df, stock_symbol)
